# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#READING THE INPUT FILE
data=pd.read_excel('/content/drive/MyDrive/BlackCoffer/Input.xlsx')[['URL_ID','URL']]

# %%
data
# Out:
#      URL_ID                                                URL
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
# [114 rows x 2 columns]

# %%
import requests
from bs4 import BeautifulSoup
# Function to extract text from a URL
def extract_text_from_url(url):
    # Send GET request to the URL
    response = requests.get(url)
    
    # Parseing the HTML content of the response using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extracting the text from the HTML content
    text = soup.get_text()
    
    return text

# Applying the function to each URL in the DataFrame
data['Text'] = data['URL'].apply(extract_text_from_url)

data
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#                                                   Text
# 0    \n\n\n\n\n\n\n\nAI in healthcare to Improve Pa...
# 1    \n\n\n\n\n\n\n\nWhat if the Creation is Taking...
# 2    \n\n\n\n\n\n\n\nWhat Jobs Will Robots Take Fro...
# 3    \n\n\n\n\n\n\n\nWill Machine Replace The Human...
# 4    \n\n\n\n\n\n\n\nWill AI Replace Us or Work Wit...
# ..                                                 ...
# 109  \n\n\n\n\n\n\n\nBlockchain for Payments | Blac...
# 110  \n\n\n\n\n\n\n\nThe future of Investing | Blac...
# 111  \n\n\n\n\n\n\n\nBig Data Analytics in Healthca...
# 112  \n\n\n\n\n\n\n\nBusiness Analytics In The Heal...
# 113  \n\n\n\n\n\n\n\nChallenges and Opportunities o...
#
# [114 rows x 3 columns]

# %%
data.Text
# Out:
# 0      \n\n\n\n\n\n\n\nAI in healthcare to Improve Pa...
# 1      \n\n\n\n\n\n\n\nWhat if the Creation is Taking...
# 2      \n\n\n\n\n\n\n\nWhat Jobs Will Robots Take Fro...
# 3      \n\n\n\n\n\n\n\nWill Machine Replace The Human...
# 4      \n\n\n\n\n\n\n\nWill AI Replace Us or Work Wit...
#                              ...
# 109    \n\n\n\n\n\n\n\nBlockchain for Payments | Blac...
# 110    \n\n\n\n\n\n\n\nThe future of Investing | Blac...
# 111    \n\n\n\n\n\n\n\nBig Data Analytics in Healthca...
# 112    \n\n\n\n\n\n\n\nBusiness Analytics In The Heal...
# 113    \n\n\n\n\n\n\n\nChallenges and Opportunities o...
# Name: Text, Length: 114, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   URL_ID  114 non-null    int64
#  1   URL     114 non-null    object
#  2   Text    114 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.8+ KB

# %%
import nltk
import string
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# #EDA

# %%
data.Text=[Text.strip() for Text in data.Text] # remove both the leading and the trailing characters
data.Text=[Text for Text in data.Text if Text] # removes empty strings, because they are considered in Python as False
data[0:10]
# Out:
#    URL_ID                                                URL  \
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...
# 1      38  https://insights.blackcoffer.com/what-if-the-c...
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...
# 3      40  https://insights.blackcoffer.com/will-machine-...
# 4      41  https://insights.blackcoffer.com/will-ai-repla...
# 5      42  https://insights.blackcoffer.com/man-and-machi...
# 6      43  https://insights.blackcoffer.com/in-future-or-...
# 7      44  https://insights.blackcoffer.com/how-neural-ne...
# 8      45  https://insights.blackcoffer.com/how-machine-l...
# 9      46  https://insights.blackcoffer.com/deep-learning...
#
#                                                 Text
# 0  AI in healthcare to Improve Patient Outcomes |...
# 1  What if the Creation is Taking Over the Creato...
# 2  What Jobs Will Robots Take From Humans in The ...
# 3  Will Machine Replace The Human in the Future o...
# 4  Will AI Replace Us or Work With Us? | Blackcof...
# 5  Will machine replace the human in the future o...
# 6  How humans and machines are evolving to work t...
# 7  Page not found | Blackcoffer Insights\n\n\n\n\...
# 8  How machine learning will affect your business...
# 9  Deep learning impact on areas of e-learning? |...

# %%
data.Text = data.Text.apply(lambda x :x.lower())          #converting all the data in lower case

# %%
data
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#                                                   Text
# 0    ai in healthcare to improve patient outcomes |...
# 1    what if the creation is taking over the creato...
# 2    what jobs will robots take from humans in the ...
# 3    will machine replace the human in the future o...
# 4    will ai replace us or work with us? | blackcof...
# ..                                                 ...
# 109  blockchain for payments | blackcoffer insights...
# 110  the future of investing | blackcoffer insights...
# 111  big data analytics in healthcare | blackcoffer...
# 112  business analytics in the healthcare industry ...
# 113  challenges and opportunities of big data in he...
#
# [114 rows x 3 columns]

# %%
import re
data['Text'] = data['Text'].apply(lambda x: re.sub('[^a-zA-Z .]', ' ', x))   #removing all the characters except ^a-zA-Z .

# %%
data
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#                                                   Text
# 0    ai in healthcare to improve patient outcomes  ...
# 1    what if the creation is taking over the creato...
# 2    what jobs will robots take from humans in the ...
# 3    will machine replace the human in the future o...
# 4    will ai replace us or work with us    blackcof...
# ..                                                 ...
# 109  blockchain for payments   blackcoffer insights...
# 110  the future of investing   blackcoffer insights...
# 111  big data analytics in healthcare   blackcoffer...
# 112  business analytics in the healthcare industry ...
# 113  challenges and opportunities of big data in he...
#
# [114 rows x 3 columns]

# %%
#STOPWORDS

# %%
Auditor=pd.read_csv("/content/drive/MyDrive/BlackCoffer/StopWords/StopWords_Auditor.txt",header=None)
Currencies=pd.read_csv("/content/drive/MyDrive/BlackCoffer/StopWords/StopWords_Currencies.txt",header=None,encoding="ISO-8859-1",sep='|' )
DatesandNumbers=pd.read_csv("/content/drive/MyDrive/BlackCoffer/StopWords/StopWords_DatesandNumbers.txt",header=None)
Generic=pd.read_csv("/content/drive/MyDrive/BlackCoffer/StopWords/StopWords_Generic.txt",header=None)
GenericLong=pd.read_csv("/content/drive/MyDrive/BlackCoffer/StopWords/StopWords_GenericLong.txt",header=None)
Geographic=pd.read_csv("/content/drive/MyDrive/BlackCoffer/StopWords/StopWords_Geographic.txt",header=None)
Names=pd.read_csv("/content/drive/MyDrive/BlackCoffer/StopWords/StopWords_Names.txt",header=None)

# %%
from nltk import word_tokenize               #calling Tokenization function 
data.Text = data.Text.astype(str)
data.Text = data.Text.apply(lambda x:x.split())            #spliting data in words

# %%
data
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#                                                   Text
# 0    [ai, in, healthcare, to, improve, patient, out...
# 1    [what, if, the, creation, is, taking, over, th...
# 2    [what, jobs, will, robots, take, from, humans,...
# 3    [will, machine, replace, the, human, in, the, ...
# 4    [will, ai, replace, us, or, work, with, us, bl...
# ..                                                 ...
# 109  [blockchain, for, payments, blackcoffer, insig...
# 110  [the, future, of, investing, blackcoffer, insi...
# 111  [big, data, analytics, in, healthcare, blackco...
# 112  [business, analytics, in, the, healthcare, ind...
# 113  [challenges, and, opportunities, of, big, data...
#
# [114 rows x 3 columns]

# %%
#convert all STOPWORDS files to string 
Auditor=Auditor.astype(str)
Currencies=Currencies.astype(str) 
DatesandNumbers=DatesandNumbers.astype(str)
Generic=Generic.astype(str)
GenericLong=GenericLong.astype(str)
Names=Names.astype(str)

# %%
#Convert all stopwords to lower case
Auditor= Auditor.applymap(lambda x:x.lower())
Currencies=Currencies.applymap(lambda x:x.lower())
DatesandNumbers=DatesandNumbers.applymap(lambda x:x.lower())
Generic=Generic.applymap(lambda x:x.lower())
GenericLong=GenericLong.applymap(lambda x:x.lower())
Geographic= Geographic.applymap(lambda x:x.lower())
Names = Names.fillna('').applymap(lambda x: x.lower())
Names= Names.applymap(lambda x:x.lower())

# %%
def clear_stopwords(Text):
      
      Text = [word for word in Text if word not in set(Auditor)]
      Text = [word for word in Text if word not in set(Currencies)]
      Text = [word for word in Text if word not in set(DatesandNumbers)]
      Text = [word for word in Text if word not in set(Generic)]
      Text = [word for word in Text if word not in set(GenericLong)]
      Text = [word for word in Text if word not in set(Geographic)]
      Text = [word for word in Text if word not in set(Names)]
      return Text

# %%
data['Text'] = data['Text'].apply(clear_stopwords)

# %%
data
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#                                                   Text
# 0    [ai, in, healthcare, to, improve, patient, out...
# 1    [what, if, the, creation, is, taking, over, th...
# 2    [what, jobs, will, robots, take, from, humans,...
# 3    [will, machine, replace, the, human, in, the, ...
# 4    [will, ai, replace, us, or, work, with, us, bl...
# ..                                                 ...
# 109  [blockchain, for, payments, blackcoffer, insig...
# 110  [the, future, of, investing, blackcoffer, insi...
# 111  [big, data, analytics, in, healthcare, blackco...
# 112  [business, analytics, in, the, healthcare, ind...
# 113  [challenges, and, opportunities, of, big, data...
#
# [114 rows x 3 columns]

# %%
data.Text = data.Text.apply(lambda x:" ".join(x))           #join the tokens into sentence again

# %%
data
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#                                                   Text
# 0    ai in healthcare to improve patient outcomes b...
# 1    what if the creation is taking over the creato...
# 2    what jobs will robots take from humans in the ...
# 3    will machine replace the human in the future o...
# 4    will ai replace us or work with us blackcoffer...
# ..                                                 ...
# 109  blockchain for payments blackcoffer insights s...
# 110  the future of investing blackcoffer insights s...
# 111  big data analytics in healthcare blackcoffer i...
# 112  business analytics in the healthcare industry ...
# 113  challenges and opportunities of big data in he...
#
# [114 rows x 3 columns]

# %%
#Importing master dictionary

# %%
positive = pd.read_csv("/content/drive/MyDrive/BlackCoffer/MasterDictionary/positive-words.txt")
negative = pd.read_csv("/content/drive/MyDrive/BlackCoffer/MasterDictionary/negative-words.txt", encoding='ISO-8859-1')

# %%
positive
# Out:
#               a+
# 0         abound
# 1        abounds
# 2      abundance
# 3       abundant
# 4     accessable
# ...          ...
# 2000    youthful
# 2001        zeal
# 2002      zenith
# 2003        zest
# 2004       zippy
#
# [2005 rows x 1 columns]

# %%
negative
# Out:
#          2-faced
# 0        2-faces
# 1       abnormal
# 2        abolish
# 3     abominable
# 4     abominably
# ...          ...
# 4777        zaps
# 4778      zealot
# 4779     zealous
# 4780   zealously
# 4781      zombie
#
# [4782 rows x 1 columns]

# %%
positive = positive.rename(columns={'a+': 'p_word'})                    #Renaming the positive and negative dataframe columns 
negative = negative.rename(columns={'2-faced': 'n_word'})

# %%
positive.p_word= positive.p_word.str.lower()
positive = positive.apply(clear_stopwords)

# %%
len(positive)
# Out:
# 2005

# %%
negative.n_word= negative.n_word.str.lower()
negative = negative.apply(clear_stopwords)

# %%
positive = positive['p_word'].to_list()
negative = negative['n_word'].to_list()

# %%
data.Text
# Out:
# 0      ai in healthcare to improve patient outcomes b...
# 1      what if the creation is taking over the creato...
# 2      what jobs will robots take from humans in the ...
# 3      will machine replace the human in the future o...
# 4      will ai replace us or work with us blackcoffer...
#                              ...
# 109    blockchain for payments blackcoffer insights s...
# 110    the future of investing blackcoffer insights s...
# 111    big data analytics in healthcare blackcoffer i...
# 112    business analytics in the healthcare industry ...
# 113    challenges and opportunities of big data in he...
# Name: Text, Length: 114, dtype: object

# %%
data.Text = data.Text.astype(str)

# %%
data['tokens'] = data['Text'].apply(lambda x: word_tokenize(x))                      #again tokenizing the data 
data
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#                                                   Text  \
# 0    ai in healthcare to improve patient outcomes b...
# 1    what if the creation is taking over the creato...
# 2    what jobs will robots take from humans in the ...
# 3    will machine replace the human in the future o...
# 4    will ai replace us or work with us blackcoffer...
# ..                                                 ...
# 109  blockchain for payments blackcoffer insights s...
# 110  the future of investing blackcoffer insights s...
# 111  big data analytics in healthcare blackcoffer i...
# 112  business analytics in the healthcare industry ...
# 113  challenges and opportunities of big data in he...
#
#                                                 tokens
# 0    [ai, in, healthcare, to, improve, patient, out...
# 1    [what, if, the, creation, is, taking, over, th...
# 2    [what, jobs, will, robots, take, from, humans,...
# 3    [will, machine, replace, the, human, in, the, ...
# 4    [will, ai, replace, us, or, work, with, us, bl...
# ..                                                 ...
# 109  [blockchain, for, payments, blackcoffer, insig...
# 110  [the, future, of, investing, blackcoffer, insi...
# 111  [big, data, analytics, in, healthcare, blackco...
# 112  [business, analytics, in, the, healthcare, ind...
# 113  [challenges, and, opportunities, of, big, data...
#
# [114 rows x 4 columns]

# %% [markdown]
# #Sentimental Analysis

# %%
data['Positive Score'] = 0
data['Negative Score'] = 0
data['Polarity Score'] = 0
data['Subjectivity Score'] = 0



i=0
p_score=0
n_score=0
while(i<len(data)):
  tokens = data['tokens'].iloc[i]                       #POSITIVE SCORE
  for a in tokens:
    if(a in positive):
      p_score+=1
      data['Positive Score'].iloc[i]=p_score
  for b in tokens:                                      #NEGATIVE SCORE
    if(b in negative):
      n_score+=1
      data['Negative Score'].iloc[i]=n_score
  #Polarity Score = (Positive Score – Negative Score)/ ((Positive Score + Negative Score) + 0.000001)
  Polarity_Score=(p_score-n_score)/((p_score+n_score)+0.000001)
  data['Polarity Score'].iloc[i]=Polarity_Score
    
  #Subjectivity Score = (Positive Score + Negative Score)/ ((Total Words after cleaning) + 0.000001)
  subjectivity_score=(p_score+n_score)/((len(tokens))+ 0.000001)
  data['Subjectivity Score'].iloc[i]=subjectivity_score
     
  p_score=0
  n_score=0
  i += 1
# Out:
# <ipython-input-105-a4f318e20a42>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Positive Score'].iloc[i]=p_score
# <ipython-input-105-a4f318e20a42>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Negative Score'].iloc[i]=n_score
# <ipython-input-105-a4f318e20a42>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Polarity Score'].iloc[i]=Polarity_Score
# <ipython-input-105-a4f318e20a42>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Subjectivity Score'].iloc[i]=subjectivity_score

# %%
data
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#                                                   Text  \
# 0    ai in healthcare to improve patient outcomes b...
# 1    what if the creation is taking over the creato...
# 2    what jobs will robots take from humans in the ...
# 3    will machine replace the human in the future o...
# 4    will ai replace us or work with us blackcoffer...
# ..                                                 ...
# 109  blockchain for payments blackcoffer insights s...
# 110  the future of investing blackcoffer insights s...
# 111  big data analytics in healthcare blackcoffer i...
# 112  business analytics in the healthcare industry ...
# 113  challenges and opportunities of big data in he...
#
#                                                 tokens  Positive Score  \
# 0    [ai, in, healthcare, to, improve, patient, out...             119
# 1    [what, if, the, creation, is, taking, over, th...             105
# 2    [what, jobs, will, robots, take, from, humans,...             105
# 3    [will, machine, replace, the, human, in, the, ...             121
# 4    [will, ai, replace, us, or, work, with, us, bl...             107
# ..                                                 ...             ...
# 109  [blockchain, for, payments, blackcoffer, insig...              60
# 110  [the, future, of, investing, blackcoffer, insi...              78
# 111  [big, data, analytics, in, healthcare, blackco...              63
# 112  [business, analytics, in, the, healthcare, ind...              70
# 113  [challenges, and, opportunities, of, big, data...              79
#
#      Negative Score  Polarity Score  Subjectivity Score
# 0                39        0.506329            0.059939
# 1                40        0.448276            0.064359
# 2                39        0.458333            0.056604
# 3                31        0.592105            0.061315
# 4                32        0.539568            0.053981
# ..              ...             ...                 ...
# 109              33        0.290323            0.054610
# 110              20        0.591837            0.042187
# 111              52        0.095652            0.058854
# 112              10        0.750000            0.054311
# 113              46        0.264000            0.067751
#
# [114 rows x 8 columns]

# %% [markdown]
# #Analysis of Readibibility

# %%
data.Text = data.Text.astype(str)
from nltk.tokenize import sent_tokenize
data['sentences'] = data['Text'].apply(lambda x: sent_tokenize(x))                  #tokenizing the sentence in data

# %%
len(data['sentences'].iloc[0])
# Out:
# 81

# %%
#AVERAGE SENTENCE LENGTH
i = 0
while i < len(data):
    words = data['tokens'].iloc[i]
    sent = data['sentences'].iloc[i]
    avg_sent_len = len(words) / len(sent)
    data.at[i, 'Average Sentence Length'] = avg_sent_len
    i += 1

# %%
#Percentage of complex word     AND Complex Word Count
data['Percentage of Complex words']=0
data['Complex Word Count']=0
vowels=['a','e','i','o','u']
count=0
complex_Word_Count=0
i = 0  # initialize i
while(i<len(data)):
 for a in data.tokens.iloc[i]:
   x=re.compile('[es|ed]$')
   if x.match(a):
    count+=0
   else:
     for j in a:
       if(j in vowels ):
         count+=1         
   if(count>2):
    complex_Word_Count+=1
   count=0
 Percentage_of_Complex_words=complex_Word_Count/len(data.tokens.iloc[i])
 data['Percentage of Complex words'].iloc[i]=Percentage_of_Complex_words
 data['Complex Word Count'].iloc[i]= complex_Word_Count
 i += 1  # increment i after each iteration
# Out:
# <ipython-input-110-92a485dd8a44>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Percentage of Complex words'].iloc[i]=Percentage_of_Complex_words
# <ipython-input-110-92a485dd8a44>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Complex Word Count'].iloc[i]= complex_Word_Count

# %%
#FOG INDEX

# %%
i = 0
while i < len(data):
    fog_index = 0.4 * (data.at[i, 'Average Sentence Length'] + data.at[i, 'Percentage of Complex words'])
    data.at[i, 'Fog Index'] = fog_index
    i += 1

# %%
#AVERAGE NO OF WORDS PER SCENTENCE

# %%
data['avg no of words per sentence'] = 0
avg_length = []
for i in range(0, len(data)):
    for sentence in data['sentences'].iloc[i]:
        words = sentence.split()
        avg_length.append(len(words))

avg_no_of_words_per_sentence = sum(avg_length)/len(avg_length)
data['avg no of words per sentence'] = avg_no_of_words_per_sentence

# %%
#WORD COUNT
data['word count'] = 0
i = 0
while(i < len(data)):
    word_count = len(data['tokens'].iloc[i])
    data.at[i, 'word count'] = word_count
    i += 1

# %%
#SYLLABLE PER WORD
vowels = ['a', 'e', 'i', 'o', 'u']
complex_Word_Count = 0
i = 0
while i < len(data):
    count = 0
    for word in data['tokens'].iloc[i]:
        if word.endswith(('es', 'ed')):
            continue
        for letter in word:
            if letter.lower() in vowels:
                count += 1
    data.at[i, 'Syllable per word'] = count
    i += 1

# %%
#PERSONAL PRONOUNS
pronouns = ['i', 'we', 'my', 'ours', 'us']
i = 0
while i < len(data):
    count = 0
    for word in data['tokens'].iloc[i]:
        if word.lower() in pronouns:
            count += 1
    data.at[i, 'personal pronouns'] = count
    i += 1

# %%
#AVERAGE WORD LENGTH
i = 0
while i < len(data):
    count = 0
    for word in data['tokens'].iloc[i]:
        count += len(word)
    avg_word_length = count / len(data['tokens'].iloc[i])
    data.at[i, 'Average Word Length'] = avg_word_length
    i += 1

# %%
data
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#                                                   Text  \
# 0    ai in healthcare to improve patient outcomes b...
# 1    what if the creation is taking over the creato...
# 2    what jobs will robots take from humans in the ...
# 3    will machine replace the human in the future o...
# 4    will ai replace us or work with us blackcoffer...
# ..                                                 ...
# 109  blockchain for payments blackcoffer insights s...
# 110  the future of investing blackcoffer insights s...
# 111  big data analytics in healthcare blackcoffer i...
# 112  business analytics in the healthcare industry ...
# 113  challenges and opportunities of big data in he...
#
#                                                 tokens  Positive Score  \
# 0    [ai, in, healthcare, to, improve, patient, out...             119
# 1    [what, if, the, creation, is, taking, over, th...             105
# 2    [what, jobs, will, robots, take, from, humans,...             105
# 3    [will, machine, replace, the, human, in, the, ...             121
# 4    [will, ai, replace, us, or, work, with, us, bl...             107
# ..                                                 ...             ...
# 109  [blockchain, for, payments, blackcoffer, insig...              60
# 110  [the, future, of, investing, blackcoffer, insi...              78
# 111  [big, data, analytics, in, healthcare, blackco...              63
# 112  [business, analytics, in, the, healthcare, ind...              70
# 113  [challenges, and, opportunities, of, big, data...              79
#
#      Negative Score  Polarity Score  Subjectivity Score  \
# 0                39        0.506329            0.059939
# 1                40        0.448276            0.064359
# 2                39        0.458333            0.056604
# 3                31        0.592105            0.061315
# 4                32        0.539568            0.053981
# ..              ...             ...                 ...
# 109              33        0.290323            0.054610
# 110              20        0.591837            0.042187
# 111              52        0.095652            0.058854
# 112              10        0.750000            0.054311
# 113              46        0.264000            0.067751
#
#                                              sentences  \
# 0    [ai in healthcare to improve patient outcomes ...
# 1    [what if the creation is taking over the creat...
# 2    [what jobs will robots take from humans in the...
# 3    [will machine replace the human in the future ...
# 4    [will ai replace us or work with us blackcoffe...
# ..                                                 ...
# 109  [blockchain for payments blackcoffer insights ...
# 110  [the future of investing blackcoffer insights ...
# 111  [big data analytics in healthcare blackcoffer ...
# 112  [business analytics in the healthcare industry...
# 113  [challenges and opportunities of big data in h...
#
#      Average Sentence Length  Percentage of Complex words  Complex Word Count  \
# 0                  32.543210                     0.348255                 918
# 1                  30.863014                     0.679538                1531
# 2                  28.584270                     0.935928                2381
# 3                  28.494253                     1.232755                3056
# 4                  29.941860                     1.471456                3789
# ..                       ...                          ...                 ...
# 109                32.750000                    37.244275               63427
# 110                29.037500                    27.614292               64148
# 111                27.521127                    33.157114               64789
# 112                43.323529                    44.350984               65329
# 113                26.739130                    35.710569               65886
#
#      Fog Index  avg no of words per sentence  word count  Syllable per word  \
# 0    13.156586                      33.32628        2636             5154.0
# 1    12.617021                      33.32628        2253             3989.0
# 2    11.808079                      33.32628        2544             4809.0
# 3    11.890803                      33.32628        2479             4618.0
# 4    12.565327                      33.32628        2575             4730.0
# ..         ...                           ...         ...                ...
# 109  27.997710                      33.32628        1703             3224.0
# 110  22.660717                      33.32628        2323             4359.0
# 111  24.271296                      33.32628        1954             3754.0
# 112  35.069806                      33.32628        1473             3050.0
# 113  24.979880                      33.32628        1845             3452.0
#
#      personal pronouns  Average Word Length
# 0                 24.0             5.676404
# 1                 29.0             5.169996
# 2                 26.0             5.526336
# 3                 43.0             5.148850
# 4                 45.0             5.289320
# ..                 ...                  ...
# 109               32.0             5.598356
# 110               41.0             5.374085
# 111               25.0             5.436029
# 112               23.0             5.991174
# 113               31.0             5.451491
#
# [114 rows x 18 columns]

# %%
data.drop(['URL_ID','Text','tokens','sentences'],axis=1,inplace=True)

# %%
data
# Out:
#                                                    URL  Positive Score  \
# 0    https://insights.blackcoffer.com/ai-in-healthc...             119
# 1    https://insights.blackcoffer.com/what-if-the-c...             105
# 2    https://insights.blackcoffer.com/what-jobs-wil...             105
# 3    https://insights.blackcoffer.com/will-machine-...             121
# 4    https://insights.blackcoffer.com/will-ai-repla...             107
# ..                                                 ...             ...
# 109  https://insights.blackcoffer.com/blockchain-fo...              60
# 110  https://insights.blackcoffer.com/the-future-of...              78
# 111  https://insights.blackcoffer.com/big-data-anal...              63
# 112  https://insights.blackcoffer.com/business-anal...              70
# 113  https://insights.blackcoffer.com/challenges-an...              79
#
#      Negative Score  Polarity Score  Subjectivity Score  \
# 0                39        0.506329            0.059939
# 1                40        0.448276            0.064359
# 2                39        0.458333            0.056604
# 3                31        0.592105            0.061315
# 4                32        0.539568            0.053981
# ..              ...             ...                 ...
# 109              33        0.290323            0.054610
# 110              20        0.591837            0.042187
# 111              52        0.095652            0.058854
# 112              10        0.750000            0.054311
# 113              46        0.264000            0.067751
#
#      Average Sentence Length  Percentage of Complex words  Complex Word Count  \
# 0                  32.543210                     0.348255                 918
# 1                  30.863014                     0.679538                1531
# 2                  28.584270                     0.935928                2381
# 3                  28.494253                     1.232755                3056
# 4                  29.941860                     1.471456                3789
# ..                       ...                          ...                 ...
# 109                32.750000                    37.244275               63427
# 110                29.037500                    27.614292               64148
# 111                27.521127                    33.157114               64789
# 112                43.323529                    44.350984               65329
# 113                26.739130                    35.710569               65886
#
#      Fog Index  avg no of words per sentence  word count  Syllable per word  \
# 0    13.156586                      33.32628        2636             5154.0
# 1    12.617021                      33.32628        2253             3989.0
# 2    11.808079                      33.32628        2544             4809.0
# 3    11.890803                      33.32628        2479             4618.0
# 4    12.565327                      33.32628        2575             4730.0
# ..         ...                           ...         ...                ...
# 109  27.997710                      33.32628        1703             3224.0
# 110  22.660717                      33.32628        2323             4359.0
# 111  24.271296                      33.32628        1954             3754.0
# 112  35.069806                      33.32628        1473             3050.0
# 113  24.979880                      33.32628        1845             3452.0
#
#      personal pronouns  Average Word Length
# 0                 24.0             5.676404
# 1                 29.0             5.169996
# 2                 26.0             5.526336
# 3                 43.0             5.148850
# 4                 45.0             5.289320
# ..                 ...                  ...
# 109               32.0             5.598356
# 110               41.0             5.374085
# 111               25.0             5.436029
# 112               23.0             5.991174
# 113               31.0             5.451491
#
# [114 rows x 14 columns]
